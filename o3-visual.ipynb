# %% [markdown]
# Load dataset

# %%
import numpy as np
from dsprites import CountingShapes, OrientationShapes

# %%
# dataset = OrientationShapes.from_path('o3-task/orientation-o3-128.npz')

# %%
# dataset = OrientationShapes(num_objs=2).from_path('o3-task/orientation-2obj-o3-128.npz')

# %%
dataset = CountingShapes.from_path('o3-task/counting-o3-128.npz')

# %%
idx = np.random.randint(dataset.__len__())

# %%
idx
# Out:
# 53647

# %% [markdown]
# Visualize a sample

# %%
dataset.display(idx)
